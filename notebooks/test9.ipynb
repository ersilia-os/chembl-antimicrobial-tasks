# %%
from collections import Counter
import pandas as pd
import numpy as np
import os

root = "."
activities_all_raw = pd.read_csv(os.path.join(root, "..", "config", "chembl_processed", "activities_preprocessed.csv"), low_memory=False)

# %%
# 8. Converting activity types to their corresponding synonyms
synonyms = pd.read_csv(os.path.join(root, "..", "config", "manual_curation", "synonyms.csv"))
for activity, syns in zip(synonyms['activity'], synonyms['synonyms']):
    for syn in syns.split(";"):
        activities_all_raw.loc[activities_all_raw['activity_type'] == syn, 'activity_type'] = activity

# %%
# 9. Keeping only the canonical unit per activity type
# Get pair counts
s = activities_all_raw[["activity_type", "unit"]].astype("string").fillna("")
out = (
s.value_counts(subset=["activity_type", "unit"], dropna=False)
    .reset_index(name="count")
    .sort_values("count", ascending=False, ignore_index=True))

# Keep the most occurent pairs and discard the others
idx = out.groupby("activity_type")['count'].idxmax()
out["keep"] = 0
out.loc[idx, "keep"] = 1

# Get canonical unit per activity type
canonical = (
    out[out["keep"] == 1]
    .set_index("activity_type")[["unit"]]
    .rename(columns={"unit": "canonical_unit"}))
canonical_map = canonical["canonical_unit"].to_dict()
activities_all_raw["canonical_unit"] = activities_all_raw["activity_type"].map(canonical_map)

# Specify canonical unit per activity type
out = out.merge(canonical, on="activity_type", how="left")

# Save pair summary
out.to_csv(os.path.join(root, "..", "config", "chembl_processed", "activity_type_unit_pairs.csv"), index=False)

# %%
out
# Out:
#        activity_type       unit    count  keep canonical_unit
# 0            POTENCY   umol.L-1  4465197     1       umol.L-1
# 1               IC50   umol.L-1  3346464     1       umol.L-1
# 2               GI50   umol.L-1  2537503     1       umol.L-1
# 3         INHIBITION          %  1926847     1              %
# 4      PERCENTEFFECT          %  1328350     1              %
# ...              ...        ...      ...   ...            ...
# 12668          ED100       umol        1     0        ug.mg-1
# 12669            ECG                   1     1
# 12670          ED145      ug/kg        1     1          ug/kg
# 12671          ED195      ug/kg        1     1          ug/kg
# 12672   PERMEABILITY  10^-8cm/s        1     0     10'-6 cm/s
#
# [12673 rows x 5 columns]

# %%
# Filter out non-canonical activity-unit pairs
keep_mask = (
    (activities_all_raw["unit"] == activities_all_raw["canonical_unit"]) |
    (activities_all_raw["unit"].isna() & activities_all_raw["canonical_unit"].isna())
)
a = activities_all_raw[keep_mask].reset_index(drop=True)

# %%
a
# Out:
#           activity_id  assay_id assay_chembl_id assay_type  \
# 0               31863     54505    CHEMBL663853          B
# 1               31864     83907    CHEMBL872937          B
# 2               31865     88152    CHEMBL693237          F
# 3               31866     83907    CHEMBL872937          B
# 4               31867     88153    CHEMBL693238          F
# ...               ...       ...             ...        ...
# 22486138     29054631   2596842   CHEMBL5739541          B
# 22486139     29054632   2596842   CHEMBL5739541          B
# 22486140     29054633   2596842   CHEMBL5739541          B
# 22486141     29054634   2596842   CHEMBL5739541          B
# 22486142     29054635   2596842   CHEMBL5739541          B
#
#           assay_confidence_score assay_organism  doc_chembl_id    tid  \
# 0                              8            NaN  CHEMBL1137930     63
# 1                              8            NaN  CHEMBL1146658  11653
# 2                              1   Homo sapiens  CHEMBL1146658  22221
# 3                              8            NaN  CHEMBL1146658  11653
# 4                              1   Homo sapiens  CHEMBL1146658  22221
# ...                          ...            ...            ...    ...
# 22486138                       9   Homo sapiens  CHEMBL5729811  19639
# 22486139                       9   Homo sapiens  CHEMBL5729811  19639
# 22486140                       9   Homo sapiens  CHEMBL5729811  19639
# 22486141                       9   Homo sapiens  CHEMBL5729811  19639
# 22486142                       9   Homo sapiens  CHEMBL5729811  19639
#
#              target_type target_organism  ...       MW  pchembl  \
# 0         SINGLE PROTEIN    Homo sapiens  ...  312.328      NaN
# 1         SINGLE PROTEIN    Homo sapiens  ...  398.374     5.60
# 2          NON-MOLECULAR             NaN  ...  398.374      NaN
# 3         SINGLE PROTEIN    Homo sapiens  ...  520.497     5.05
# 4          NON-MOLECULAR             NaN  ...  520.497      NaN
# ...                  ...             ...  ...      ...      ...
# 22486138  SINGLE PROTEIN    Homo sapiens  ...  436.468      NaN
# 22486139  SINGLE PROTEIN    Homo sapiens  ...  436.468      NaN
# 22486140  SINGLE PROTEIN    Homo sapiens  ...  435.484     6.30
# 22486141  SINGLE PROTEIN    Homo sapiens  ...  435.484      NaN
# 22486142  SINGLE PROTEIN    Homo sapiens  ...  435.484      NaN
#
#          activity_comment standard_text    value      unit  activity_type  \
# 0                       0             0  100.000  umol.L-1           IC50
# 1                       0             0    2.500  umol.L-1           IC50
# 2                       0             0   50.000  umol.L-1           IC50
# 3                       0             0    9.000  umol.L-1           IC50
# 4                       0             0      NaN  umol.L-1           IC50
# ...                   ...           ...      ...       ...            ...
# 22486138                0             0      NaN       NaN            KON
# 22486139                0             0      NaN       s-1           KOFF
# 22486140                0             0    0.503  umol.L-1           IC50
# 22486141                0             0      NaN       NaN            KON
# 22486142                0             0      NaN       s-1           KOFF
#
#           relation  pchembl_calculated canonical_unit
# 0                >            4.000000       umol.L-1
# 1                =            5.602060       umol.L-1
# 2                >            4.301030       umol.L-1
# 3                =            5.045757       umol.L-1
# 4                =                 NaN       umol.L-1
# ...            ...                 ...            ...
# 22486138         =                 NaN            NaN
# 22486139         =                 NaN            s-1
# 22486140         =            6.298432       umol.L-1
# 22486141         =                 NaN            NaN
# 22486142         =                 NaN            s-1
#
# [22486143 rows x 24 columns]

# %%
sum(out[out['keep'] == 1]['count'].tolist())
# Out:
# 22486224

# %%
sum(out[out['keep'] == 0]['count'].tolist())
# Out:
# 1554763

# %%
22486224+1554763
# Out:
# 24040987

# %%
out[out['keep'] == 1]
# Out:
#         activity_type      unit    count keep canonical_unit
# 0             POTENCY  umol.L-1  4465197    1       umol.L-1
# 1                IC50  umol.L-1  3346464    1       umol.L-1
# 2                GI50  umol.L-1  2537503    1       umol.L-1
# 3          INHIBITION         %  1926847    1              %
# 4       PERCENTEFFECT         %  1328350    1              %
# ...               ...       ...      ...  ...            ...
# 12649            EC91  umol.L-1        1    1       umol.L-1
# 12655  FULLINHIBITION  umol.L-1        1    1       umol.L-1
# 12669             ECG       NaN        1    1            NaN
# 12670           ED145     ug/kg        1    1          ug/kg
# 12671           ED195     ug/kg        1    1          ug/kg
#
# [6012 rows x 5 columns]

# %%
# out[out['keep'] == 0].reset_index(drop=True).drop(columns={'keep'}).to_csv(os.path.join())
