# %%
from collections import Counter
import pandas as pd
import os

root = "."
activities_all_raw = pd.read_csv(os.path.join(root, "..", "config", "chembl_processed", "activities_preprocessed.csv"), low_memory=False)
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[1], line 6
#       3 import os
#       5 root = "."
# ----> 6 activities_all_raw = pd.read_csv(os.path.join(root, "..", "config", "chembl_processed", "activities_preprocessed.csv"), low_memory=False)
#       8 synonyms = pd.read_csv(os.path.join(root, "..", "config", "manual_curation", "synonyms.csv"))
#
# File ~/miniconda3/envs/camt/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/camt/lib/python3.10/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File ~/miniconda3/envs/camt/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File ~/miniconda3/envs/camt/lib/python3.10/site-packages/pandas/io/parsers/c_parser_wrapper.py:239, in CParserWrapper.read(self, nrows)
#     236         data = _concatenate_chunks(chunks)
#     238     else:
# --> 239         data = self._reader.read(nrows)
#     240 except StopIteration:
#     241     if self._first_chunk:
#
# File parsers.pyx:820, in pandas._libs.parsers.TextReader.read()
#
# File parsers.pyx:914, in pandas._libs.parsers.TextReader._read_rows()
#
# File parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
# 8. Converting activity types to their corresponding synonyms
synonyms = pd.read_csv(os.path.join(root, "..", "config", "manual_curation", "synonyms.csv"))
for activity, syns in zip(synonyms['activity'], synonyms['synonyms']):
    for syn in syns.split(";"):
        activities_all_raw.loc[activities_all_raw['activity_type'] == syn, 'column_name'] = activity

# %%
c = activities_preprocessed[activities_preprocessed['activity_type'].str.contains("MIC", na=False)]['activity_type'].tolist()

# %%
Counter(c)
# Out:
# Counter({'MIC': 774558,
#          'MIC90': 35799,
#          'MIC50': 29478,
#          'MIC80': 18098,
#          'MIC99': 6813,
#          'MIC100': 4225,
#          '-LOGMIC': 4042,
#          'MIC>99': 3935,
#          'MIC95': 2887,
#          'MIC=>90': 1970,
#          'MIC>90': 920,
#          'MIC=>80': 766,
#          'FT>MIC': 687,
#          'LOG1MMIC': 612,
#          'LOG2MIC': 543,
#          'NOOFCUREDMICE': 534,
#          'MIC>95': 448,
#          'MIC=>50': 429,
#          'LOG(1MIC)': 407,
#          'NOOFMICECURED': 355,
#          '-LOG(1MIC)': 324,
#          'MIC999': 308,
#          'MIC=<90': 283,
#          'RATIOAUCMIC': 247,
#          'FAUCMIC': 245,
#          'NOOFMICE': 238,
#          'HYPOGLYCEMICACTIVITY': 224,
#          'MIC=>95': 174,
#          'LOG1MIC': 173,
#          'MIC>98': 172,
#          'PMIC50': 159,
#          'NOOFMICEPROTECTED': 119,
#          'MIC>85': 105,
#          'HYPOTHERMICEFFECT': 98,
#          'P(1MIC)': 82,
#          'LOGMIC': 79,
#          'T>MIC': 73,
#          'PMIC': 69,
#          'MIC=<50': 64,
#          'MIC70': 58,
#          'KIMICROM': 58,
#          'PROTECTEDMICE': 57,
#          'REMOVALOFMICROFILARIAE': 55,
#          'GM-MIC': 52,
#          'SYSTEMICEFFECT': 50,
#          'NOOFDEADMICE': 45,
#          'NOOFMICESURVIVED': 44,
#          'LOG(1MIC>90)': 40,
#          'MIC=<80': 40,
#          'TBMIC': 39,
#          'GMMIC': 37,
#          'HYPERGLYCEMICACTIVITY': 37,
#          'MIC50MIC90': 36,
#          'LOG1MIC(MML-1)': 31,
#          'MIC+MIC-': 31,
#          'SUBMIC': 29,
#          'MIC75': 26,
#          'NOOFMICERECEOVERED': 24,
#          'FCMAXMIC': 23,
#          'MICE': 20,
#          'HEMODYNAMICCHANGE': 20,
#          'NOOFMICEEFFECTEDNOOFTREATED': 20,
#          'NOOFDEATHSMICEINJECTED': 17,
#          'MIC>80': 16,
#          'P10MIC': 15,
#          'LOGPMIC': 14,
#          'ANTIMICROBIALACTIVITY': 14,
#          'NOOFMICEDEADDAYDIED': 14,
#          'THERMODYNAMICSOLUBILITY': 14,
#          'MIC98': 14,
#          'NOOFMICEPROTECTEDTESTED': 12,
#          'NOOFMICEALIVE': 11,
#          'MICEWITHLESIONS': 11,
#          '%T>MIC': 11,
#          'MICEINFI': 10,
#          'CYTOPLASMICVACUOLIZATION': 10,
#          'T>MIC90': 10,
#          'MPCMIC': 9,
#          'HYPOCALCEMICACTIVITY': 8,
#          'MICROSOMALSTABILITY': 8,
#          'EUDISMICRATIO': 8,
#          '-LN(MIC)': 8,
#          'EC90MIC': 6,
#          'BATHOCHROMICSHIFT': 6,
#          'HYPOCHROMICSHIFT': 6,
#          'NOOFMICEDEAD': 6,
#          '1MIC': 6,
#          'NOOFMICEWITHOUTTUMORS': 5,
#          'NOOFVIRUSFREEMICE': 5,
#          'PLASMAMIC': 5,
#          'NOOFMICESURVIVING>6MONTHS': 5,
#          'F%T>MIC': 5,
#          'PARAPARETICMICE': 4,
#          'NOOFMICEINFECTEDTOTAL': 4,
#          'CHANGESINDYNAMICCOMPLIANCE': 4,
#          'CRITICALMICELLECONCENTRATION': 2,
#          'MIC60': 2,
#          'HYPOGLYCEMIC': 1,
#          'FRPAT10MICROM': 1,
#          'CONTROLATTHEDOSEOF50MICROGMOUSE': 1,
#          'CONTROLATTHEDOSEOF500MICROGMOUSE': 1,
#          'ANTI-ARHYTHMIC': 1,
#          'RANGEOFMIC': 1,
#          'RATIOED50MIC50': 1,
#          'MIC97': 1,
#          'MIC82': 1,
#          'MIC65': 1})
