# %%
import pandas as pd
import numpy as np
import os

# %%
activities_all_raw = pd.read_csv(os.path.join(".", "..", "config", 'chembl_processed', 'activities_preprocessed.csv'), low_memory=False)

# %%
def create_text_flag(df):

    cond_nan = (df['activity_comment'] == 0) & (df['standard_text'] == 0)
    cond_pos = (df['activity_comment'] == 1) | (df['standard_text'] == 1)
    cond_neg = (df['activity_comment'] == -1) | (df['standard_text'] == -1)

    # Detect row-level conflicts
    conflict = cond_pos & cond_neg
    if conflict.any():
        raise ValueError(
            "Conflicting labels (contains both 1 and -1):\n"
            + df.loc[conflict, ["compound_chembl_id", "activity_comment", "standard_text"]].head(20).to_string())

    # Assign row-level label
    df["text_flag"] = np.nan
    df.loc[cond_pos, "text_flag"] = 1
    df.loc[cond_neg, "text_flag"] = -1
    df.loc[cond_nan, "text_flag"] = 0

    # Remove original fields
    df = df.drop(columns=['activity_comment', 'standard_text'])

    return df

# %%
activities_all_raw = create_text_flag(activities_all_raw)

# %%
activities_all_raw
# Out:
#           activity_id  assay_id assay_chembl_id assay_type  \
# 0               31863     54505    CHEMBL663853          B
# 1               31864     83907    CHEMBL872937          B
# 2               31865     88152    CHEMBL693237          F
# 3               31866     83907    CHEMBL872937          B
# 4               31867     88153    CHEMBL693238          F
# ...               ...       ...             ...        ...
# 24040982     29054631   2596842   CHEMBL5739541          B
# 24040983     29054632   2596842   CHEMBL5739541          B
# 24040984     29054633   2596842   CHEMBL5739541          B
# 24040985     29054634   2596842   CHEMBL5739541          B
# 24040986     29054635   2596842   CHEMBL5739541          B
#
#           assay_confidence_score assay_organism  doc_chembl_id    tid  \
# 0                              8            NaN  CHEMBL1137930     63
# 1                              8            NaN  CHEMBL1146658  11653
# 2                              1   Homo sapiens  CHEMBL1146658  22221
# 3                              8            NaN  CHEMBL1146658  11653
# 4                              1   Homo sapiens  CHEMBL1146658  22221
# ...                          ...            ...            ...    ...
# 24040982                       9   Homo sapiens  CHEMBL5729811  19639
# 24040983                       9   Homo sapiens  CHEMBL5729811  19639
# 24040984                       9   Homo sapiens  CHEMBL5729811  19639
# 24040985                       9   Homo sapiens  CHEMBL5729811  19639
# 24040986                       9   Homo sapiens  CHEMBL5729811  19639
#
#              target_type target_organism  ...  \
# 0         SINGLE PROTEIN    Homo sapiens  ...
# 1         SINGLE PROTEIN    Homo sapiens  ...
# 2          NON-MOLECULAR             NaN  ...
# 3         SINGLE PROTEIN    Homo sapiens  ...
# 4          NON-MOLECULAR             NaN  ...
# ...                  ...             ...  ...
# 24040982  SINGLE PROTEIN    Homo sapiens  ...
# 24040983  SINGLE PROTEIN    Homo sapiens  ...
# 24040984  SINGLE PROTEIN    Homo sapiens  ...
# 24040985  SINGLE PROTEIN    Homo sapiens  ...
# 24040986  SINGLE PROTEIN    Homo sapiens  ...
#
#                                            canonical_smiles       MW pchembl  \
# 0                  c1ccc(-c2nc3c(-c4nc5ccccc5o4)cccc3o2)cc1  312.328     NaN
# 1         Cc1ccc2oc(-c3cccc(N4C(=O)c5ccc(C(=O)O)cc5C4=O)...  398.374    5.60
# 2         Cc1ccc2oc(-c3cccc(N4C(=O)c5ccc(C(=O)O)cc5C4=O)...  398.374     NaN
# 3         COc1ccccc1-c1ccc2oc(-c3ccc(OC)c(N4C(=O)c5ccc(C...  520.497    5.05
# 4         COc1ccccc1-c1ccc2oc(-c3ccc(OC)c(N4C(=O)c5ccc(C...  520.497     NaN
# ...                                                     ...      ...     ...
# 24040982  CC(C)Oc1cc2c(OC[C@@H]3CCC(=O)N3)ncc(-c3cccc(=O...  436.468     NaN
# 24040983  CC(C)Oc1cc2c(OC[C@@H]3CCC(=O)N3)ncc(-c3cccc(=O...  436.468     NaN
# 24040984  Cc1nccc(-c2cnc(OC[C@@H]3CCC(=O)N3)c3cc(OC(C)C)...  435.484    6.30
# 24040985  Cc1nccc(-c2cnc(OC[C@@H]3CCC(=O)N3)c3cc(OC(C)C)...  435.484     NaN
# 24040986  Cc1nccc(-c2cnc(OC[C@@H]3CCC(=O)N3)c3cc(OC(C)C)...  435.484     NaN
#
#          bao_endpoint    value      unit activity_type  relation  \
# 0         BAO_0000190  100.000  umol.L-1          IC50         >
# 1         BAO_0000190    2.500  umol.L-1          IC50         =
# 2         BAO_0000190   50.000  umol.L-1          IC50         >
# 3         BAO_0000190    9.000  umol.L-1          IC50         =
# 4         BAO_0000190      NaN  umol.L-1          IC50         =
# ...               ...      ...       ...           ...       ...
# 24040982  BAO_0000480      NaN       NaN           KON         =
# 24040983  BAO_0000179      NaN       s-1          KOFF         =
# 24040984  BAO_0000190    0.503  umol.L-1          IC50         =
# 24040985  BAO_0000480      NaN       NaN           KON         =
# 24040986  BAO_0000179      NaN       s-1          KOFF         =
#
#          pchembl_calculated text_flag
# 0                  4.000000       0.0
# 1                  5.602060       0.0
# 2                  4.301030       0.0
# 3                  5.045757       0.0
# 4                       NaN       0.0
# ...                     ...       ...
# 24040982                NaN       0.0
# 24040983                NaN       0.0
# 24040984           6.298432       0.0
# 24040985                NaN       0.0
# 24040986                NaN       0.0
#
# [24040987 rows x 23 columns]

# %%
s = activities_all_raw[["activity_type", "unit", 'text_flag']].astype("string").fillna("")
out = (
s.value_counts(subset=["activity_type", "unit", 'text_flag'], dropna=False)
    .reset_index(name="count")
    .sort_values("count", ascending=False, ignore_index=True)
)
total_count = out['count'].sum()
out['cumulative_prop'] = (out['count'].cumsum() / total_count).round(3)

# %%
out
# Out:
#        activity_type          unit text_flag    count  cumulative_prop
# 0               IC50      umol.L-1       0.0  3207559            0.133
# 1            POTENCY      umol.L-1       0.0  2875824            0.253
# 2               GI50      umol.L-1      -1.0  2220580            0.345
# 3         INHIBITION             %       0.0  1708901            0.416
# 4      PERCENTEFFECT             %       0.0  1328350            0.472
# ...              ...           ...       ...      ...              ...
# 13544           VMAX    pM 0.5hr-1       0.0        1            1.000
# 13545             KD  umol.L-1.s-1       0.0        1            1.000
# 13546     IZAARAARLV                    -1.0        1            1.000
# 13547     IZAARAARLV             %       0.0        1            1.000
# 13548              K   10^-1(1/Ms)       0.0        1            1.000
#
# [13549 rows x 5 columns]
