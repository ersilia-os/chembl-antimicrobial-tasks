# %%
import pandas as pd
import zipfile
import json
import os
from tqdm import tqdm
import numpy as np
from collections import Counter
from IPython.display import display, HTML

pd.set_option("display.max_columns", None)
pd.set_option("display.expand_frame_repr", False)
pd.set_option("display.width", 2000)
pd.set_option("display.max_colwidth", None)

display(HTML("""
<style>
.dataframe td, .dataframe th {
    white-space: nowrap !important;
}
</style>
"""))
# Out:
# <style>
# .dataframe td, .dataframe th {
#     white-space: nowrap !important;
# }
# </style>

# %%
root = "."
pathogen_code = "mtuberculosis"

# %%
# Load master table
master = pd.read_csv(os.path.join(root, "..", "output", pathogen_code, "assays_master.csv"))

# %%
Counter(master['dataset_type'])
# Out:
# Counter({'quantitative': 8753, 'qualitative': 1479, 'none': 244, 'mixed': 45})

# %%
print("\n".join(master.columns.to_list()))
# Out:
# assay_id
# assay_type
# assay_organism
# organism_curated
# doc_chembl_id
# target_type
# target_type_curated
# target_chembl_id
# target_organism
# strain
# atcc_id
# mutations
# known_drug_resistances
# media
# activity_type
# unit
# canonical_unit
# activities
# nan_values
# cpds
# direction
# activity_comment_counts
# standard_text_count
# equal
# higher
# lower
# dataset_type
# expert_cutoff
# pos_qt
# ratio_qt
# cpds_qt
# min_
# p1
# p25
# p50
# p75
# p99
# max_
# pos_ql
# ratio_ql
# cpds_ql
# clusters_0.3
# clusters_0.6
# clusters_0.85

# %%
COLS = ['assay_id', 'assay_organism', 'target_type', 'target_type_curated', 'activity_type', 'unit', 
        'activities', 'nan_values', "cpds", 'dataset_type', 'expert_cutoff', "pos_qt", "ratio_qt", "cpds_qt", 'pos_ql', 'ratio_ql', 'cpds_ql']


# master[master['dataset_type'] == 'qualitative'][COLS][:50]
master[COLS][:50]
# Out:
#          assay_id                                assay_organism      target_type target_type_curated  activity_type      unit  activities  nan_values   cpds  dataset_type  expert_cutoff  pos_qt  ratio_qt  cpds_qt  pos_ql  ratio_ql  cpds_ql
# 0   CHEMBL4649948                    Mycobacterium tuberculosis        UNCHECKED            ORGANISM  PERCENTEFFECT         %       93555           0  86589  quantitative           50.0  1268.0     0.015  86589.0     NaN       NaN      NaN
# 1   CHEMBL4649949                    Mycobacterium tuberculosis        UNCHECKED            ORGANISM  PERCENTEFFECT         %      101515           0  86575  quantitative           50.0  2181.0     0.025  86575.0     NaN       NaN      NaN
# 2   CHEMBL4649971                    Mycobacterium tuberculosis         ORGANISM            ORGANISM  PERCENTEFFECT         %       68619           0  68613  quantitative           50.0   934.0     0.014  68613.0     NaN       NaN      NaN
# 3   CHEMBL4649972                    Mycobacterium tuberculosis  PROTEIN COMPLEX     PROTEIN COMPLEX  PERCENTEFFECT         %       68616           0  68610          none            NaN     NaN       NaN      NaN     NaN       NaN      NaN
# 4   CHEMBL4649941                    Mycobacterium tuberculosis   SINGLE PROTEIN      SINGLE PROTEIN  PERCENTEFFECT         %       67381           0  66941  quantitative           50.0    40.0     0.001  66941.0     NaN       NaN      NaN
# 5   CHEMBL4649965                    Mycobacterium tuberculosis   SINGLE PROTEIN      SINGLE PROTEIN  PERCENTEFFECT         %       66597           0  66591  quantitative           50.0   303.0     0.005  66591.0     NaN       NaN      NaN
# 6   CHEMBL4649957                    Mycobacterium tuberculosis   SINGLE PROTEIN      SINGLE PROTEIN  PERCENTEFFECT         %       65033           0  65027  quantitative           50.0    64.0     0.001  65027.0     NaN       NaN      NaN
# 7   CHEMBL4649961                    Mycobacterium tuberculosis         ORGANISM            ORGANISM  PERCENTEFFECT         %       53170           0  53165  quantitative           50.0   898.0     0.017  53165.0     NaN       NaN      NaN
# 8   CHEMBL4649947                    Mycobacterium tuberculosis   SINGLE PROTEIN      SINGLE PROTEIN  PERCENTEFFECT         %        8841           0   8841  quantitative           50.0    12.0     0.001   8841.0     NaN       NaN      NaN
# 9   CHEMBL4649949                    Mycobacterium tuberculosis        UNCHECKED            ORGANISM           IC50  umol.L-1        2468           0   2468  quantitative           10.0    90.0     0.036   2468.0     NaN       NaN      NaN
# 10  CHEMBL4649948                    Mycobacterium tuberculosis        UNCHECKED            ORGANISM           IC50  umol.L-1        2466           0   2466  quantitative           10.0    68.0     0.028   2466.0     NaN       NaN      NaN
# 11  CHEMBL1794349                                           NaN   SINGLE PROTEIN      SINGLE PROTEIN           AC50  umol.L-1        2126           0   2121         mixed            1.0    37.0     0.017   2121.0  1380.0     0.654   2111.0
# 12  CHEMBL1794426                                           NaN   SINGLE PROTEIN      SINGLE PROTEIN           EC50  umol.L-1        2121           0   2116         mixed            1.0   316.0     0.149   2116.0  1873.0     0.920   2036.0
# 13  CHEMBL1794324                                           NaN   SINGLE PROTEIN      SINGLE PROTEIN           AC50  umol.L-1        2069           0   2064         mixed            1.0   118.0     0.057   2064.0  1690.0     0.838   2016.0
# 14  CHEMBL2098495  Mycobacterium tuberculosis variant bovis BCG         ORGANISM            ORGANISM          MIC90  umol.L-1         776           0    776  quantitative           10.0   776.0     1.000    776.0     NaN       NaN      NaN
# 15  CHEMBL4649972                    Mycobacterium tuberculosis  PROTEIN COMPLEX     PROTEIN COMPLEX           IC50  umol.L-1         674           0    674          none            NaN     NaN       NaN      NaN     NaN       NaN      NaN
# 16  CHEMBL4649957                    Mycobacterium tuberculosis   SINGLE PROTEIN      SINGLE PROTEIN           IC50  umol.L-1         612           0    597  quantitative            1.0     0.0     0.000    597.0     NaN       NaN      NaN
# 17  CHEMBL4649941                    Mycobacterium tuberculosis   SINGLE PROTEIN      SINGLE PROTEIN           IC50  umol.L-1         914           0    439  quantitative            1.0     0.0     0.000    439.0     NaN       NaN      NaN
# 18  CHEMBL2094262                    Mycobacterium tuberculosis         ORGANISM            ORGANISM     INHIBITION         %         399           0    399  quantitative           50.0    66.0     0.165    399.0     NaN       NaN      NaN
# 19  CHEMBL2094261                    Mycobacterium tuberculosis         ORGANISM            ORGANISM     INHIBITION         %         399           0    399  quantitative           50.0    11.0     0.028    399.0     NaN       NaN      NaN
# 20  CHEMBL2114816              Mycobacterium tuberculosis H37Rv   SINGLE PROTEIN      SINGLE PROTEIN           AC50  umol.L-1         369           0    369         mixed            1.0     4.0     0.011    369.0   229.0     0.621    369.0
# 21  CHEMBL4649965                    Mycobacterium tuberculosis   SINGLE PROTEIN      SINGLE PROTEIN           IC50  umol.L-1         601           0    302  quantitative            1.0     1.0     0.003    302.0     NaN       NaN      NaN
# 22  CHEMBL2114860              Mycobacterium tuberculosis UT205   SINGLE PROTEIN      SINGLE PROTEIN           AC50  umol.L-1         298           0    298         mixed            1.0    55.0     0.185    298.0   298.0     1.000    298.0
# 23  CHEMBL4649971                    Mycobacterium tuberculosis         ORGANISM            ORGANISM           IC50  umol.L-1         269           0    200  quantitative           10.0    24.0     0.120    200.0     NaN       NaN      NaN
# 24  CHEMBL2098496              Mycobacterium tuberculosis H37Rv         ORGANISM            ORGANISM          MIC90  umol.L-1         177           0    177  quantitative           10.0   177.0     1.000    177.0     NaN       NaN      NaN
# 25  CHEMBL2354305                                           NaN   SINGLE PROTEIN      SINGLE PROTEIN           IC50  umol.L-1         174           0    174         mixed            1.0    28.0     0.161    174.0   149.0     0.856    174.0
# 26  CHEMBL5345966                    Mycobacterium tuberculosis         ORGANISM            ORGANISM          MIC99  umol.L-1         172           0    172  quantitative           10.0    51.0     0.297    172.0     NaN       NaN      NaN
# 27  CHEMBL5345967                    Mycobacterium tuberculosis         ORGANISM            ORGANISM          MIC99  umol.L-1         172           0    172  quantitative           10.0    45.0     0.262    172.0     NaN       NaN      NaN
# 28  CHEMBL4333704                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         164           0    164  quantitative           10.0   106.0     0.646    164.0     NaN       NaN      NaN
# 29  CHEMBL4388638                    Mycobacterium tuberculosis         ORGANISM            ORGANISM     INHIBITION         %         146           0    146  quantitative           50.0    49.0     0.336    146.0     NaN       NaN      NaN
# 30  CHEMBL4388634                    Mycobacterium tuberculosis   SINGLE PROTEIN      SINGLE PROTEIN           IC50  umol.L-1         146           0    146  quantitative            1.0     1.0     0.007    146.0     NaN       NaN      NaN
# 31  CHEMBL2032580                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         136           0    136  quantitative           10.0    45.0     0.331    136.0     NaN       NaN      NaN
# 32  CHEMBL3857706              Mycobacterium tuberculosis H37Ra    NON-MOLECULAR       NON-MOLECULAR            MIC  umol.L-1         131           0    131          none            NaN     NaN       NaN      NaN     NaN       NaN      NaN
# 33  CHEMBL1614471              Mycobacterium tuberculosis H37Rv   SINGLE PROTEIN      SINGLE PROTEIN           IC50  umol.L-1         125           0    125         mixed            1.0     1.0     0.008    125.0   125.0     1.000    125.0
# 34  CHEMBL3887425                                           NaN   SINGLE PROTEIN      SINGLE PROTEIN           IC50  umol.L-1         124           0    124  quantitative            1.0    35.0     0.282    124.0     NaN       NaN      NaN
# 35  CHEMBL1634496                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         121           0    121  quantitative           10.0   121.0     1.000    121.0     NaN       NaN      NaN
# 36  CHEMBL1634497                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         121           0    121  quantitative           10.0    89.0     0.736    121.0     NaN       NaN      NaN
# 37   CHEMBL747348                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         118           0    118  quantitative           10.0     0.0     0.000    118.0     NaN       NaN      NaN
# 38  CHEMBL1049617                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0   115.0     0.991    116.0     NaN       NaN      NaN
# 39  CHEMBL1049618                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0   106.0     0.914    116.0     NaN       NaN      NaN
# 40  CHEMBL3832772                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0    72.0     0.621    116.0     NaN       NaN      NaN
# 41  CHEMBL3832763                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0   100.0     0.862    116.0     NaN       NaN      NaN
# 42  CHEMBL3832767                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0    56.0     0.483    116.0     NaN       NaN      NaN
# 43  CHEMBL3832770                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0    68.0     0.586    116.0     NaN       NaN      NaN
# 44  CHEMBL3832766                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0    42.0     0.362    116.0     NaN       NaN      NaN
# 45  CHEMBL3832771                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0    47.0     0.405    116.0     NaN       NaN      NaN
# 46  CHEMBL3832765                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0    42.0     0.362    116.0     NaN       NaN      NaN
# 47  CHEMBL3832764                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0    93.0     0.802    116.0     NaN       NaN      NaN
# 48  CHEMBL3832776                    Mycobacterium tuberculosis         ORGANISM            ORGANISM          MIC90  umol.L-1         116           0    116  quantitative           10.0    25.0     0.216    116.0     NaN       NaN      NaN
# 49  CHEMBL3832777                    Mycobacterium tuberculosis         ORGANISM            ORGANISM            MIC  umol.L-1         116           0    116  quantitative           10.0    21.0     0.181    116.0     NaN       NaN      NaN

# %%
COLS = ['assay_id', 'assay_organism', 'target_type', 'target_type_curated', 'activity_type', 'unit', 
        'activities', 'nan_values', "cpds", 'dataset_type', 'expert_cutoff', "pos_qt", "ratio_qt", "cpds_qt", 'pos_ql', 'ratio_ql', 'cpds_ql', 'clusters_0.6']

master[(master['ratio_qt'] > 0.5) | (master['ratio_ql'] > 0.5) ][COLS][:50].reset_index(drop=True)
# Out:
#          assay_id                                assay_organism     target_type target_type_curated activity_type      unit  activities  nan_values  cpds  dataset_type  expert_cutoff  pos_qt  ratio_qt  cpds_qt  pos_ql  ratio_ql  cpds_ql  clusters_0.6
# 0   CHEMBL1794349                                           NaN  SINGLE PROTEIN      SINGLE PROTEIN          AC50  umol.L-1        2126           0  2121         mixed            1.0    37.0     0.017   2121.0  1380.0     0.654   2111.0          1648
# 1   CHEMBL1794426                                           NaN  SINGLE PROTEIN      SINGLE PROTEIN          EC50  umol.L-1        2121           0  2116         mixed            1.0   316.0     0.149   2116.0  1873.0     0.920   2036.0          1649
# 2   CHEMBL1794324                                           NaN  SINGLE PROTEIN      SINGLE PROTEIN          AC50  umol.L-1        2069           0  2064         mixed            1.0   118.0     0.057   2064.0  1690.0     0.838   2016.0          1650
# 3   CHEMBL2098495  Mycobacterium tuberculosis variant bovis BCG        ORGANISM            ORGANISM         MIC90  umol.L-1         776           0   776  quantitative           10.0   776.0     1.000    776.0     NaN       NaN      NaN           581
# 4   CHEMBL2114816              Mycobacterium tuberculosis H37Rv  SINGLE PROTEIN      SINGLE PROTEIN          AC50  umol.L-1         369           0   369         mixed            1.0     4.0     0.011    369.0   229.0     0.621    369.0           316
# 5   CHEMBL2114860              Mycobacterium tuberculosis UT205  SINGLE PROTEIN      SINGLE PROTEIN          AC50  umol.L-1         298           0   298         mixed            1.0    55.0     0.185    298.0   298.0     1.000    298.0           202
# 6   CHEMBL2098496              Mycobacterium tuberculosis H37Rv        ORGANISM            ORGANISM         MIC90  umol.L-1         177           0   177  quantitative           10.0   177.0     1.000    177.0     NaN       NaN      NaN           137
# 7   CHEMBL2354305                                           NaN  SINGLE PROTEIN      SINGLE PROTEIN          IC50  umol.L-1         174           0   174         mixed            1.0    28.0     0.161    174.0   149.0     0.856    174.0           172
# 8   CHEMBL4333704                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         164           0   164  quantitative           10.0   106.0     0.646    164.0     NaN       NaN      NaN            48
# 9   CHEMBL1614471              Mycobacterium tuberculosis H37Rv  SINGLE PROTEIN      SINGLE PROTEIN          IC50  umol.L-1         125           0   125         mixed            1.0     1.0     0.008    125.0   125.0     1.000    125.0           108
# 10  CHEMBL1634496                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         121           0   121  quantitative           10.0   121.0     1.000    121.0     NaN       NaN      NaN             7
# 11  CHEMBL1634497                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         121           0   121  quantitative           10.0    89.0     0.736    121.0     NaN       NaN      NaN             7
# 12  CHEMBL1049617                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         116           0   116  quantitative           10.0   115.0     0.991    116.0     NaN       NaN      NaN             2
# 13  CHEMBL1049618                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         116           0   116  quantitative           10.0   106.0     0.914    116.0     NaN       NaN      NaN             2
# 14  CHEMBL3832772                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         116           0   116  quantitative           10.0    72.0     0.621    116.0     NaN       NaN      NaN           108
# 15  CHEMBL3832763                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         116           0   116  quantitative           10.0   100.0     0.862    116.0     NaN       NaN      NaN           108
# 16  CHEMBL3832770                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         116           0   116  quantitative           10.0    68.0     0.586    116.0     NaN       NaN      NaN           108
# 17  CHEMBL3832764                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         116           0   116  quantitative           10.0    93.0     0.802    116.0     NaN       NaN      NaN           108
# 18  CHEMBL3832774                    Mycobacterium tuberculosis        ORGANISM            ORGANISM         MIC90  umol.L-1         116           0   116  quantitative           10.0    62.0     0.534    116.0     NaN       NaN      NaN           108
# 19  CHEMBL3832773                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         116           0   116  quantitative           10.0    69.0     0.595    116.0     NaN       NaN      NaN           108
# 20  CHEMBL5246903                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         114           0   114  quantitative           10.0   114.0     1.000    114.0     NaN       NaN      NaN            17
# 21  CHEMBL1839642                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         113           0   113  quantitative           10.0   112.0     0.991    113.0     NaN       NaN      NaN             6
# 22  CHEMBL1839643                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1         113           0   113  quantitative           10.0    75.0     0.664    113.0     NaN       NaN      NaN             6
# 23  CHEMBL4011046                    Mycobacterium tuberculosis        ORGANISM            ORGANISM            GI         %         103           0   103  quantitative           50.0   103.0     1.000    103.0     NaN       NaN      NaN            13
# 24  CHEMBL4011042  Mycobacterium tuberculosis variant bovis BCG        ORGANISM            ORGANISM            GI         %         103           0   103  quantitative           50.0   103.0     1.000    103.0     NaN       NaN      NaN            13
# 25  CHEMBL4011010  Mycobacterium tuberculosis variant bovis BCG        ORGANISM            ORGANISM         MIC50  umol.L-1         103           0   103  quantitative           10.0    60.0     0.583    103.0     NaN       NaN      NaN            13
# 26  CHEMBL4150258  Mycobacterium tuberculosis variant bovis BCG        ORGANISM            ORGANISM         MIC50  umol.L-1          99           0    99  quantitative           10.0    69.0     0.697     99.0     NaN       NaN      NaN             9
# 27  CHEMBL4150258  Mycobacterium tuberculosis variant bovis BCG        ORGANISM            ORGANISM         MIC90  umol.L-1          99           0    99  quantitative           10.0    51.0     0.515     99.0     NaN       NaN      NaN             9
# 28   CHEMBL940872                    Mycobacterium tuberculosis        ORGANISM            ORGANISM            GI         %          96           0    96  quantitative           50.0    78.0     0.812     96.0     NaN       NaN      NaN            10
# 29  CHEMBL3267866                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          94           0    94  quantitative           10.0    60.0     0.638     94.0     NaN       NaN      NaN            38
# 30  CHEMBL2318567                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          94           0    94  quantitative           10.0    55.0     0.585     94.0     NaN       NaN      NaN            26
# 31  CHEMBL5156632                    Mycobacterium tuberculosis        ORGANISM            ORGANISM         MIC90  umol.L-1          87           0    87  quantitative           10.0    60.0     0.690     87.0     NaN       NaN      NaN             7
# 32  CHEMBL4841891  Mycobacterium tuberculosis variant bovis BCG        ORGANISM            ORGANISM         MIC90  umol.L-1          86           0    86  quantitative           10.0    53.0     0.616     86.0     NaN       NaN      NaN            13
# 33  CHEMBL1794344                                           NaN  SINGLE PROTEIN      SINGLE PROTEIN          AC50  umol.L-1          82           0    82         mixed            1.0     6.0     0.073     82.0    79.0     0.963     82.0            61
# 34  CHEMBL1947387                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          80           0    80  quantitative           10.0    70.0     0.875     80.0     NaN       NaN      NaN             7
# 35  CHEMBL2421471                    Mycobacterium tuberculosis        ORGANISM            ORGANISM            GI         %          79           0    79  quantitative           50.0    41.0     0.519     79.0     NaN       NaN      NaN            11
# 36  CHEMBL2447071                    Mycobacterium tuberculosis        ORGANISM            ORGANISM         MIC99  umol.L-1          79           0    79  quantitative           10.0    47.0     0.595     79.0     NaN       NaN      NaN            13
# 37  CHEMBL2447069                    Mycobacterium tuberculosis        ORGANISM            ORGANISM         MIC99  umol.L-1          79           0    79  quantitative           10.0    58.0     0.734     79.0     NaN       NaN      NaN            13
# 38  CHEMBL1737995              Mycobacterium tuberculosis H37Rv  SINGLE PROTEIN      SINGLE PROTEIN          IC90  umol.L-1          76           0    76   qualitative            NaN     NaN       NaN      NaN    76.0     1.000     76.0            61
# 39  CHEMBL1018758                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          75           0    75  quantitative           10.0    69.0     0.920     75.0     NaN       NaN      NaN             7
# 40  CHEMBL4135530                    Mycobacterium tuberculosis        ORGANISM            ORGANISM         MIC90  umol.L-1          75           0    75  quantitative           10.0    67.0     0.893     75.0     NaN       NaN      NaN             4
# 41  CHEMBL4052219                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          75           0    75  quantitative           10.0    68.0     0.907     75.0     NaN       NaN      NaN             4
# 42  CHEMBL4052220                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          75           0    75  quantitative           10.0    50.0     0.667     75.0     NaN       NaN      NaN             4
# 43  CHEMBL2350721                    Mycobacterium tuberculosis        ORGANISM            ORGANISM    INHIBITION         %          72          29    72         mixed           50.0    27.0     0.628     43.0     0.0     0.000     29.0            22
# 44  CHEMBL2184408                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          71           0    71  quantitative           10.0    71.0     1.000     71.0     NaN       NaN      NaN             4
# 45  CHEMBL3619020                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          71           0    71  quantitative           10.0    37.0     0.521     71.0     NaN       NaN      NaN            14
# 46  CHEMBL4406692                    Mycobacterium tuberculosis  SINGLE PROTEIN      SINGLE PROTEIN          IC50  umol.L-1          71           0    71  quantitative            1.0    43.0     0.606     71.0     NaN       NaN      NaN             3
# 47  CHEMBL4425484                    Mycobacterium tuberculosis        ORGANISM            ORGANISM         MIC90  umol.L-1          70           0    70  quantitative           10.0    47.0     0.671     70.0     NaN       NaN      NaN             8
# 48  CHEMBL1019550                    Mycobacterium tuberculosis        ORGANISM            ORGANISM    INHIBITION         %          70           0    70  quantitative           50.0    70.0     1.000     70.0     NaN       NaN      NaN             4
# 49   CHEMBL750947                    Mycobacterium tuberculosis        ORGANISM            ORGANISM           MIC  umol.L-1          70           0    69  quantitative           10.0    43.0     0.623     69.0     NaN       NaN      NaN            19
