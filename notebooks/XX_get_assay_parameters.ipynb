# %%
import pandas as pd
import zipfile
import json
import os

# %%
root = "."
pathogen_code = "mtuberculosis"

# Get assay data
ASSAYS = pd.read_csv(os.path.join(root, "..", "output", pathogen_code, "assays.csv"), low_memory=False)[:450]

# Set path to parameters
PATH_TO_PARAMETERS = os.path.join(root, "..", "output", pathogen_code, "parameters")

# For each assay
PARAMETERS = []
for assay_id, assay_type, act_type, unit in zip(ASSAYS["assay_id"], ASSAYS["assay_type"], ASSAYS["activity_type"], ASSAYS["unit"]):

    # Change unit format
    if type(unit) != str:
        unit = 'nan'
    else:
        unit = unit.replace('/', 'FwdS').replace(" ", "__")

    # Load JSON file
    filepath = os.path.join(PATH_TO_PARAMETERS, "_".join([assay_id, act_type, unit]) + "_parameters.json")
    with open(filepath, "r") as f:
        js = json.load(f)

    # Collect values
    p = [
        js.get("assay_id", assay_id),
        js.get("assay_type", assay_type),
        js.get("activity_type", act_type),
        js.get("unit", unit),
        js.get("organism", ""),
        js.get("strain", ""),
        ", ".join(js.get("mutations", [])),
        ", ".join(js.get("known_drug_resistances", [])),
        js.get("media", ""),
        ]
    PARAMETERS.append(p)

# to pd DataFrame
PARAMETERS = pd.DataFrame(PARAMETERS, columns=["Assay ID", "Assay type", "Activity Type", "Unit", "Organism", "Strain", "Mutations", "Known drug resistances", "Media"])

# Save to TSV
PARAMETERS.to_csv(os.path.join(root, "..", "output", pathogen_code, "assays_parameters.tsv"), sep='\t', index=False)

# %%
PARAMETERS[PARAMETERS['Mutations'] != '']
# Out:
#           Assay ID Assay type Activity Type      Unit  \
# 80   CHEMBL3387309          F    INHIBITION         %
# 86   CHEMBL4425486          F         MIC90  umol.L-1
# 122  CHEMBL4425484          F         MIC90  umol.L-1
# 184  CHEMBL4425485          F         MIC90  umol.L-1
# 191  CHEMBL5623473          F         MIC99  umol.L-1
# 196  CHEMBL3387308          F         MIC99       nan
# 232  CHEMBL4308568          F           MIC  umol.L-1
# 254  CHEMBL4189875          B            KI  umol.L-1
# 264  CHEMBL4395372          F         MIC90  umol.L-1
# 287  CHEMBL4059067          B       MIC=<90  umol.L-1
# 293  CHEMBL5246901          F          EC50  umol.L-1
# 359  CHEMBL4392088          B       MIC=<90  umol.L-1
#
#                              Organism                   Strain  \
# 80         Mycobacterium tuberculosis                    H37Rv
# 86         Mycobacterium tuberculosis                 mc2 6220
# 122        Mycobacterium tuberculosis                 mc2 6220
# 184        Mycobacterium tuberculosis                 mc2 6220
# 191        Mycobacterium tuberculosis  CNCTC My 331/88 (H37Rv)
# 196        Mycobacterium tuberculosis                    H37Rv
# 232        Mycobacterium tuberculosis                    H37Rv
# 254        Mycobacterium tuberculosis
# 264        Mycobacterium tuberculosis            H37Rv SRMV2.6
# 287  Mycobacterium tuberculosis H37Rv
# 293        Mycobacterium tuberculosis                    W4-E1
# 359        Mycobacterium tuberculosis                    H37Rv
#
#                                    Mutations Known drug resistances  \
# 80                                   Rv3161c
# 86                       panCD/lysA deletion
# 122            panCD deletion, lysA deletion
# 184               panCD/lysA deletion mutant
# 191                           dprE1 (Rv3790)
# 196                                  Rv3161c
# 232                                    mmpL3
# 254                           IMPDH2deltaCBS
# 264                          GuaB2 Tyr487Cys
# 287  single nucleotide polymorphism in pks13
# 293                           EthA Gly343Ala            ethionamide
# 359                           D1644G, N1640K
#
#                           Media
# 80
# 86
# 122
# 184
# 191  Sulas semisynthetic medium
# 196
# 232
# 254
# 264
# 287
# 293
# 359
