# %%
import pandas as pd

# %%
df = pd.read_csv("../config/chembl_processed/activities_preprocessed.csv", low_memory=False)

# %%
df
# Out:
#           activity_id  assay_id assay_chembl_id assay_type  \
# 0               31863     54505    CHEMBL663853          B
# 1               31864     83907    CHEMBL872937          B
# 2               31865     88152    CHEMBL693237          F
# 3               31866     83907    CHEMBL872937          B
# 4               31867     88153    CHEMBL693238          F
# ...               ...       ...             ...        ...
# 24040982     29054631   2596842   CHEMBL5739541          B
# 24040983     29054632   2596842   CHEMBL5739541          B
# 24040984     29054633   2596842   CHEMBL5739541          B
# 24040985     29054634   2596842   CHEMBL5739541          B
# 24040986     29054635   2596842   CHEMBL5739541          B
#
#           assay_confidence_score assay_organism  doc_chembl_id    tid  \
# 0                              8            NaN  CHEMBL1137930     63
# 1                              8            NaN  CHEMBL1146658  11653
# ...

# %%
df[df['assay_chembl_id'] == "CHEMBL1614289"]
# Out:
#          activity_id  assay_id assay_chembl_id assay_type  \
# 3439141      3894999    688697   CHEMBL1614289          F
# 3439143      3895000    688697   CHEMBL1614289          F
# 3439144      3895001    688697   CHEMBL1614289          F
# 3439145      3895002    688697   CHEMBL1614289          F
# 3439146      3895003    688697   CHEMBL1614289          F
# ...              ...       ...             ...        ...
# 3449027      3910570    688697   CHEMBL1614289          F
# 3449028      3910571    688697   CHEMBL1614289          F
# 3449029      3910572    688697   CHEMBL1614289          F
# 3449030      3910573    688697   CHEMBL1614289          F
# 3449031      3910574    688697   CHEMBL1614289          F
#
#          assay_confidence_score assay_organism  doc_chembl_id    tid  \
# 3439141                       0            NaN  CHEMBL1201862  22226
# 3439143                       0            NaN  CHEMBL1201862  22226
# ...
